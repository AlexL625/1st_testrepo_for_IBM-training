# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Yipeng Li__
# Financial Manager to Data Scientist

# %% [markdown]
# _I am interested in Data Science, because it is the future, and being a Data Scientist sounds quite cool_

# %% [markdown]
# ### My code is a simple example using Python language.

# %%
total = 0
while total < 100:
    total += 1
print(total)
# Out:
# 100

# %% [markdown]
# - 1
# - 2
# ![image-asset.jpeg](attachment:image-asset.jpeg)
#   [The Big Red](https://www.cornell.edu/)
